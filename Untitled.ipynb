# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df_tracks = pd.read_csv(r'C:\Users\chinm\Jupyter\Spotify EDA\tracks.csv')

# %%
df_tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450    0   -13.338     1       0.4510
# 1   1922-06-01         0.695  0.2630    0   -22.136     1       0.9570
# 2   1922-03-21         0.434  0.1770    1   -21.180     1       0.0512
# 3   1922-03-21         0.321  0.0946    7   -27.961     1       0.0504
# 4         1922         0.402  0.1580    3   -16.900     0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674            0.7440     0.151    0.127  104.851               3
# 1         0.797            0.0000     0.148    0.655  102.009               1
# 2         0.994            0.0218     0.212    0.457  130.418               5
# 3         0.995            0.9180     0.104    0.397  169.980               3
# 4         0.989            0.1300     0.311    0.196  103.220               4

# %%
df_null = pd.isnull(df_tracks).sum()
df_null
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 586672 entries, 1970-01-01 00:00:00 to 1970-01-01 00:00:00.000586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   explicit          586672 non-null  int64
#  4   artists           586672 non-null  object
#  5   id_artists        586672 non-null  object
#  6   release_date      586672 non-null  object
#  7   danceability      586672 non-null  float64
#  8   energy            586672 non-null  float64
#  9   key               586672 non-null  int64
#  10  loudness          586672 non-null  float64
#  11  mode              586672 non-null  int64
#  12  speechiness       586672 non-null  float64
#  13  acousticness      586672 non-null  float64
#  14  instrumentalness  586672 non-null  float64
#  15  liveness          586672 non-null  float64
#  16  valence           586672 non-null  float64
#  17  tempo             586672 non-null  float64
#  18  time_signature    586672 non-null  int64
#  19  duration          586672 non-null  int64
# dtypes: float64(9), int64(6), object(5)
# memory usage: 94.0+ MB

# %%
total_names = df_tracks.name.shape
total_names
# Out:
# (586672,)

# %%
total_percent = (df_null / total_names) * 100 
total_percent
# Out:
# id                  0.000000
# name                0.012102
# popularity          0.000000
# duration_ms         0.000000
# explicit            0.000000
# artists             0.000000
# id_artists          0.000000
# release_date        0.000000
# danceability        0.000000
# energy              0.000000
# key                 0.000000
# loudness            0.000000
# mode                0.000000
# speechiness         0.000000
# acousticness        0.000000
# instrumentalness    0.000000
# liveness            0.000000
# valence             0.000000
# tempo               0.000000
# time_signature      0.000000
# dtype: float64

# %% [markdown]
# # Least popular Songs

# %%
sort_df = df_tracks.sort_values('popularity' , ascending = True).head(10)
sort_df
# Out:
#                                                    id  \
# 1970-01-01 00:00:00.000546130  181rTRhCcggZPwP2TUcVqm
# 1970-01-01 00:00:00.000546222  0yOCz3V5KMm8l1T8EFc60i
# 1970-01-01 00:00:00.000546221  0y48Hhwe52099UqYjegRCO
# 1970-01-01 00:00:00.000546220  0xCmgtf9ka07hkZg3D6PaV
# 1970-01-01 00:00:00.000546219  0tBXS3VuCPX7KWUFH2nros
# 1970-01-01 00:00:00.000546218  0qrKnQtYDVJhKFAXTHYVS9
# 1970-01-01 00:00:00.000546217  0nqsDxOeKSwEzp3AUQAAqS
# 1970-01-01 00:00:00.000546216  0kGEdsxVLYjCdfxM9tbezd
# 1970-01-01 00:00:00.000546215  0bc3PUZurUUXrY7yqoOxjq
# 1970-01-01 00:00:00.000546214  0Wwm0ruSjYMIiWG0nyAI1F
#
#                                                                             name  \
# 1970-01-01 00:00:00.000546130       Newspaper Reports On Abner, 20 February 1935
# 1970-01-01 00:00:00.000546222                                             恋は水の上で
# 1970-01-01 00:00:00.000546221                                              私の誕生日
# 1970-01-01 00:00:00.000546220                                エル・チョクロ (EL CHOCLO)
# 1970-01-01 00:00:00.000546219                                           恋は不思議なもの
# 1970-01-01 00:00:00.000546218                         ゆうべはどうしたの (WHATSA MALLA U)
# 1970-01-01 00:00:00.000546217  Screen Director's Playhouse, Music For Million...
# 1970-01-01 00:00:00.000546216                                             ブルーマンボ
# 1970-01-01 00:00:00.000546215  Screen Director's Playhouse, Trade Winds direc...
# loudness           -9.243000   -6.48200     5.376
# mode                1.000000    1.00000     1.000
# speechiness         0.044300    0.07630     0.971
# acousticness        0.422000    0.78500     0.996
# instrumentalness    0.000024    0.00955     1.000
# liveness            0.139000    0.27800     1.000
# valence             0.564000    0.76900     1.000
# tempo             117.384000  136.32100   246.381
# time_signature      4.000000    4.00000     5.000
# duration          215.000000  264.00000  5621.000

# %% [markdown]
# # Most Popular

# %%
most_popular = df_tracks.query('popularity > 90', inplace = False).sort_values('popularity', ascending = False)
most_popular[:10]
# Out:
#                                                    id  \
# 1970-01-01 00:00:00.000093802  4iJyoBOLtHqaGxP12qzhQI
# 1970-01-01 00:00:00.000093803  7lPN2DXiMsVn7XUKtOW1CS
# 1970-01-01 00:00:00.000093804  3Ofmpyhv5UAQ70mENzB277
# 1970-01-01 00:00:00.000092810  5QO79kh1waicV47BqGRL3g
# 1970-01-01 00:00:00.000092811  6tDDoYIxWvMLTdKpjFkc1B
# 1970-01-01 00:00:00.000092813  0VjIjW4GlUZAMYd2vXMi3b
# 1970-01-01 00:00:00.000093805  7MAibcTli4IisCtbHKrGMh
# 1970-01-01 00:00:00.000092814  6f3Slt0GbA2bPZlz0aIFXN
# 1970-01-01 00:00:00.000091866  60ynsPSSKe6O3sfwRnIBRf
# 1970-01-01 00:00:00.000092816  3FAJ6O0NOHQV8Mc5Ri6ENp
#
#                                                                  name  \
# 1970-01-01 00:00:00.000093802  Peaches (feat. Daniel Caesar & Giveon)
# 1970-01-01 00:00:00.000093803                         drivers license
# 1970-01-01 00:00:00.000093804                  Astronaut In The Ocean
# 1970-01-01 00:00:00.000092810                         Save Your Tears
# 1970-01-01 00:00:00.000092811                               telepatía
# 1970-01-01 00:00:00.000092813                         Blinding Lights
# 1970-01-01 00:00:00.000093805                     Leave The Door Open
# 1970-01-01 00:00:00.000092814                            The Business
# 1970-01-01 00:00:00.000091866                                 Streets
# 1970-01-01 00:00:00.000092816                  Heartbreak Anniversary
#
#                                popularity  explicit  \
# 1970-01-01 00:00:00.000093802         100         1
# 1970-01-01 00:00:00.000093803          99         1
# 1970-01-01 00:00:00.000093804          98         0
# 1970-01-01 00:00:00.000092810          97         1
# 1970-01-01 00:00:00.000092811          97         0
# 1970-01-01 00:00:00.000092813          96         0
# 1970-01-01 00:00:00.000093805          96         0
# 1970-01-01 00:00:00.000092814          95         0
# 1970-01-01 00:00:00.000091866          94         1
# 1970-01-01 00:00:00.000092816          94         0
#
#                                                                       artists  \
# 1970-01-01 00:00:00.000093802    ['Justin Bieber', 'Daniel Caesar', 'Giveon']
# 1970-01-01 00:00:00.000093803                              ['Olivia Rodrigo']
# 1970-01-01 00:00:00.000093804                                 ['Masked Wolf']
# 1970-01-01 00:00:00.000092810                                  ['The Weeknd']
# 1970-01-01 00:00:00.000092811                                  ['Kali Uchis']
# 1970-01-01 00:00:00.000092813                                  ['The Weeknd']
# 1970-01-01 00:00:00.000093805  ['Bruno Mars', 'Anderson .Paak', 'Silk Sonic']
# 1970-01-01 00:00:00.000092814                                      ['Tiësto']
# 1970-01-01 00:00:00.000091866                                    ['Doja Cat']
# 1970-01-01 00:00:00.000092816                                      ['Giveon']
#
#                                                                       id_artists  \
# 1970-01-01 00:00:00.000093802  ['1uNFoZAHBGtllmzznpCI3s', '20wkVLutqVOYrc0kxF...
# 1970-01-01 00:00:00.000093803                         ['1McMsnEElThX1knmY4oliG']
# 1970-01-01 00:00:00.000093804                         ['1uU7g3DNSbsu0QjSEqZtEd']
# 1970-01-01 00:00:00.000092810                         ['1Xyo4u8uXC1ZmMpatF05PJ']
# 1970-01-01 00:00:00.000092811                         ['1U1el3k54VvEUzo3ybLPlM']
# 1970-01-01 00:00:00.000092813                         ['1Xyo4u8uXC1ZmMpatF05PJ']
# 1970-01-01 00:00:00.000093805  ['0du5cEVh5yTK9QJze8zA0C', '3jK9MiCrA42lLAdMGU...
# 1970-01-01 00:00:00.000092814                         ['2o5jDhtHVPhrJdv3cEQ99Z']
# 1970-01-01 00:00:00.000091866                         ['5cj0lLjcoR7YOSnhnX0Po5']
# 1970-01-01 00:00:00.000092816                         ['4fxd5Ee7UefO4CUXgwJ7IP']
#
#                               release_date  danceability  energy  key  \
# 1970-01-01 00:00:00.000093802   2021-03-19         0.677   0.696    0
# 1970-01-01 00:00:00.000093803   2021-01-08         0.585   0.436   10
# 1970-01-01 00:00:00.000093804   2021-01-06         0.778   0.695    4
# 1970-01-01 00:00:00.000092810   2020-03-20         0.680   0.826    0
# 1970-01-01 00:00:00.000092811   2020-12-04         0.653   0.524   11
# 1970-01-01 00:00:00.000092813   2020-03-20         0.514   0.730    1
# 1970-01-01 00:00:00.000093805   2021-03-05         0.586   0.616    5
# 1970-01-01 00:00:00.000092814   2020-09-16         0.798   0.620    8
# 1970-01-01 00:00:00.000091866   2019-11-07         0.749   0.463   11
# 1970-01-01 00:00:00.000092816   2020-03-27         0.449   0.465    0
#
#                                loudness  mode  speechiness  acousticness  \
# 1970-01-01 00:00:00.000093802    -6.181     1       0.1190       0.32100
# 1970-01-01 00:00:00.000093803    -8.761     1       0.0601       0.72100
# 1970-01-01 00:00:00.000093804    -6.865     0       0.0913       0.17500
# 1970-01-01 00:00:00.000092810    -5.487     1       0.0309       0.02120
# 1970-01-01 00:00:00.000092811    -9.016     0       0.0502       0.11200
# 1970-01-01 00:00:00.000092813    -5.934     1       0.0598       0.00146
# 1970-01-01 00:00:00.000093805    -7.964     1       0.0324       0.18200
# 1970-01-01 00:00:00.000092814    -7.079     0       0.2320       0.41400
# 1970-01-01 00:00:00.000091866    -8.433     1       0.0828       0.20800
# 1970-01-01 00:00:00.000092816    -8.964     1       0.0791       0.52400
#
#                                instrumentalness  liveness  valence    tempo  \
# 1970-01-01 00:00:00.000093802          0.000000    0.4200    0.464   90.030
# 1970-01-01 00:00:00.000093803          0.000013    0.1050    0.132  143.874
# 1970-01-01 00:00:00.000093804          0.000000    0.1500    0.472  149.996
# 1970-01-01 00:00:00.000092810          0.000012    0.5430    0.644  118.051
# 1970-01-01 00:00:00.000092811          0.000000    0.2030    0.553   83.970
# 1970-01-01 00:00:00.000092813          0.000095    0.0897    0.334  171.005
# 1970-01-01 00:00:00.000093805          0.000000    0.0927    0.719  148.088
# 1970-01-01 00:00:00.000092814          0.019200    0.1120    0.235  120.031
# 1970-01-01 00:00:00.000091866          0.037100    0.3370    0.190   90.028
# 1970-01-01 00:00:00.000092816          0.000001    0.3030    0.543   89.087
#
#                                time_signature  duration
# 1970-01-01 00:00:00.000093802               4       198
# 1970-01-01 00:00:00.000093803               4       242
# 1970-01-01 00:00:00.000093804               4       133
# 1970-01-01 00:00:00.000092810               4       216
# 1970-01-01 00:00:00.000092811               4       160
# 1970-01-01 00:00:00.000092813               4       200
# 1970-01-01 00:00:00.000093805               4       242
# 1970-01-01 00:00:00.000092814               4       164
# 1970-01-01 00:00:00.000091866               4       227
# 1970-01-01 00:00:00.000092816               3       198

# %%
df_tracks.set_index("release_date" , inplace = True)
df_tracks.index = pd.to_datetime(df_tracks.index)
# df_tracks.index = df_tracks[df_tracks.index].dt.strftime('%Y')
df_tracks.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 df_tracks.set_index("release_date" , inplace = True)
#       2 df_tracks.index = pd.to_datetime(df_tracks.index)
#       3 # df_tracks.index = df_tracks[df_tracks.index].dt.strftime('%Y')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5859, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5856                 missing.append(col)
#    5858 if missing:
# -> 5859     raise KeyError(f"None of {missing} are in the columns")
#    5861 if inplace:
#    5862     frame = self
#
# KeyError: "None of ['release_date'] are in the columns"

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 586672 entries, 1922-02-22 to 2015-07-01
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   explicit          586672 non-null  int64
#  4   artists           586672 non-null  object
#  5   id_artists        586672 non-null  object
#  6   danceability      586672 non-null  float64
#  7   energy            586672 non-null  float64
#  8   key               586672 non-null  int64
#  9   loudness          586672 non-null  float64
#  10  mode              586672 non-null  int64
#  11  speechiness       586672 non-null  float64
#  12  acousticness      586672 non-null  float64
#  13  instrumentalness  586672 non-null  float64
#  14  liveness          586672 non-null  float64
#  15  valence           586672 non-null  float64
#  16  tempo             586672 non-null  float64
#  17  time_signature    586672 non-null  int64
#  18  duration          586672 non-null  int64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 89.5+ MB

# %%
df_tracks["duration"] = df_tracks["duration_ms"].apply(lambda x: round(x/1000))
df_tracks.drop("duration_ms" , inplace = True, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'duration_ms'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 df_tracks["duration"] = df_tracks["duration_ms"].apply(lambda x: round(x/1000))
#       2 df_tracks.drop("duration_ms" , inplace = True, axis = 1)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'duration_ms'

# %%
df_tracks.duration.head()
# Out:
# release_date
# 1922-02-22    127
# 1922-06-01     98
# 1922-03-21    182
# 1922-03-21    177
# 1922          163
# Name: duration, dtype: int64

# %% [markdown]
# # Correlation Map

# %%
corr_df = df_tracks.drop(["key" , "mode" , "explicit", "id_artists", "id", "name", "artists"], axis = 1)
corr_df = corr_df.corr(method = "pearson")
corr_df.head()
plt.figure(figsize = (14, 6))
heatmap = sns.heatmap(corr_df, annot = True, fmt = ".1g", vmin=-1, vmax = 1, center = 0, cmap = "Greens", linewidth = 1, linecolor = "Black")
heatmap.set_title("Correlation heatmap between variables")
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation = 90)
# Out:
# [Text(0.5, 0, 'popularity'),
#  Text(1.5, 0, 'danceability'),
#  Text(2.5, 0, 'energy'),
#  Text(3.5, 0, 'loudness'),
#  Text(4.5, 0, 'speechiness'),
#  Text(5.5, 0, 'acousticness'),
#  Text(6.5, 0, 'instrumentalness'),
#  Text(7.5, 0, 'liveness'),
#  Text(8.5, 0, 'valence'),
#  Text(9.5, 0, 'tempo'),
#  Text(10.5, 0, 'time_signature'),
#  Text(11.5, 0, 'duration')]
